# %% [markdown]
# ## Connect to and Test Database connection

# %%
import pyexasol as pe
import csv

# %%
C=pe.connect(dsn='192.168.56.102:8563',user='sys',password='exasol')

# %%
stmt=C.execute("SELECT * FROM EXA_ALL_USERS")
for row in stmt:
    print(row)
# Out:
# ('SYS', None, None, 'SYS is the system user and possesses universal privileges. Please remember to change the initial password of this privileged user.')

# %% [markdown]
# ## Create US Cities Database

# %%
stmt=C.execute("CREATE TABLE IF NOT EXISTS AOL_SCHEMA.US_GEO \
( \
ZIPCODE int, \
CITY varchar(100), \
STATE_NAME varchar(100), \
STATE_ABBR varchar(100), \
COUNTY varchar(200), \
LATITUDE numeric, \
LONGITUDE numeric, \
ACCURACY int \
)")

# %%
with open('./datasrc/US.txt') as f:
    reader = csv.reader(f,delimiter='\t')
    for row in reader:
        params = {'zip': row[1], 'city':row[2], 'state':row[3], 'abbr':row[4], 'county':row[5], 
                    'lat':row[9],'long':row[10], 'est':row[11]}
    
        query = "INSERT INTO AOL_SCHEMA.US_GEO( \
                    ZIPCODE, CITY, STATE_NAME, STATE_ABBR, \
                    COUNTY, LATITUDE, LONGITUDE, ACCURACY) \
                    VALUES({zip},{city},{state},{abbr},{county},{lat},{long},{est});"
        C.execute(query,params)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-a4e5da7aa0b8> in <module>
#       9                     COUNTY, LATITUDE, LONGITUDE, ACCURACY) \
#      10                     VALUES({zip},{city},{state},{abbr},{county},{lat},{long},{est});"
# ---> 11         C.execute(query,params)
#
# ~\.virtualenvs\BusInt\lib\site-packages\pyexasol\connection.py in execute(self, query, query_params)
#     161         Return ExaStatement object
#     162         """
# --> 163         self._last_stmt = self.cls_statement(self, query, query_params)
#     164
#     165         return self._last_stmt
#
# ~\.virtualenvs\BusInt\lib\site-packages\pyexasol\statement.py in __init__(self, connection, query, query_params, prepare, **options)
#      45             self._prepare()
#      46         else:
# ---> 47             self._execute()
#      48
#      49     def __iter__(self):
#
# ...
